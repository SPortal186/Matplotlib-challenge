# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# # Observations.
# 1.According to our study Capomulin and Ramicane were the two most tested drugs, with 230 Timepoints for Capomulin and 228 Timepoints for Ramicane, which also has better results in reducing the size of the tumors.
# 2.Study was almost equally conducted among male and females mice, with only 0.8% difference, where we have our numbers from Clean Data sheet(counts: 123-female, and 125-male).
# 3.The correlation coefficient of 0.84 also indicates that our two variables, which are Tumor Volume and Weight of the mouse are related in a positive linear sense. When mice are smaller they tend to have smaller tumors and when their weight increases we can see that the average tumor volume also increases.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_data = pd.merge(mouse_metadata, study_results, how='outer', on='Mouse ID')
# Display the data table for preview
merged_data.head(-1)
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1887     z969     Naftisol  Male           9          30         20
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
total_mice = len(merged_data["Mouse ID"].value_counts())
total_mice
# Out:
# 249

# %%
duplicate_ids = merged_data.loc[merged_data.duplicated(subset=["Mouse ID","Timepoint"]),"Mouse ID"].unique()
duplicate_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mice_duplicates = merged_data[merged_data.duplicated(subset=['Mouse ID','Timepoint'])]
mice_duplicates.head()
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
merged_data = merged_data.loc[merged_data['Mouse ID'] != "g989"]
merged_data.head(-1)
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1887     z969     Naftisol  Male           9          30         20
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
total_clean_mice = len(merged_data["Mouse ID"].value_counts())
total_clean_mice_df = total_clean_mice
total_clean_mice_df
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
regimen_data = merged_data.groupby("Drug Regimen")
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume.

tumor_mean = (regimen_data["Tumor Volume (mm3)"].mean())
tumor_median = (regimen_data["Tumor Volume (mm3)"].median())
tumor_variance = (regimen_data["Tumor Volume (mm3)"].var())
tumor_standard_deviation = (regimen_data["Tumor Volume (mm3)"].std())   
tumor_sem = (regimen_data["Tumor Volume (mm3)"].sem())

# Assemble the resulting series into a single summary dataframe.
summary_tatistics = pd.DataFrame({"Volume Mean": tumor_mean,
                                 "Volume Median": tumor_median,
                                 "Volume Variance": tumor_variance,
                                 "Volume Standard Deviation": tumor_standard_deviation,
                                 "Volume SEM": tumor_sem})
summary_tatistics
# Out:
#               Volume Mean  Volume Median  Volume Variance  \
# Drug Regimen
# Capomulin       40.675741      41.557809        24.947764
# Ceftamin        52.591172      51.776157        39.290177
# Infubinol       52.884795      51.820584        43.128684
# Ketapril        55.235638      53.698743        68.553577
# Naftisol        54.331565      52.509285        66.173479
# Placebo         54.033581      52.288934        61.168083
# Propriva        52.320930      50.446266        43.852013
# Ramicane        40.216745      40.673236        23.486704
# Stelasyn        54.233149      52.431737        59.450562
# Zoniferol       53.236507      51.818479        48.533355
#
#               Volume Standard Deviation  Volume SEM
# Drug Regimen
# Capomulin                      4.994774    0.329346
# Ceftamin                       6.268188    0.469821
# Infubinol                      6.567243    0.492236
# Ketapril                       8.279709    0.603860
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

aggregation_data = regimen_data.agg({'Tumor Volume (mm3)': (['mean', 'median', 'var', 'std', 'sem'])})
aggregation_data
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
regimen_plot_data = merged_data.groupby("Drug Regimen").count()["Timepoint"]
plot_df = pd.DataFrame(regimen_plot_data)
plot_df
# Out:
#               Timepoint
# Drug Regimen
# Capomulin           230
# Ceftamin            178
# Infubinol           178
# Ketapril            188
# Naftisol            186
# Placebo             181
# Propriva            148
# Ramicane            228
# Stelasyn            181
# Zoniferol           182

# %%
timepoints_plot = plot_df.plot(kind="bar", figsize=(10,5))
plt.xlabel("Drug Regimen")
plt.ylabel("Total Timepoints")
plt.title("Timepoints per Drug Regimen")

plt.savefig("../Images/Pandas_timepoints_plot_bar.png")
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
#regimen_plot_data = merged_data.groupby("Drug Regimen").count()["Timepoint"]
#plot_df = pd.DataFrame(regimen_plot_data)

x_axis = np.arange(len(regimen_plot_data))
tick_locations = [value for value in x_axis]
plt.figure(figsize=(10,5))

new_plot_df = plot_df.reset_index()

plt.bar(x_axis, plot_df['Timepoint'], color='b', align="center")
plt.xticks(tick_locations, new_plot_df['Drug Regimen'], rotation="vertical")


plt.xlim(-0.75, len(regimen_plot_data))
plt.ylim(0, max(plot_df["Timepoint"])+10)
plt.xlabel("Drug Regimen")
plt.ylabel("Total Timepoints")
plt.title("Timepoints per Drug Regimen")

plt.savefig("../Images/py_timepoints_plot_bar.png")
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender = merged_data.groupby(["Mouse ID", "Sex"])
gender_df = pd.DataFrame(gender.size())
mice_gender = pd.DataFrame(gender_df.groupby(["Sex"]).count())
mice_gender.columns = ["Counts"] 

colors = ["pink", "green"]
explode = (0.05, 0)
pie_pandas = mice_gender.plot.pie(y='Counts', explode = explode, startangle=90, colors=colors, autopct="%1.1f%%")
plt.title('Male vs Female Mouse Distribution', fontsize = 14)
plt.axis("equal")
plt.ylabel('Sex', fontsize = 12)
plt.savefig("../Images/pandas_pie_plot.png")
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender = ["Male", "Female"]
counts = [125, 123]
colors = ["lightblue", "lightcoral"]
explode = (0.1, 0)
plt.pie(counts, explode=explode, labels=gender, colors=colors, autopct="%1.1f%%", startangle=90, shadow=True)
plt.title("Male vs Female Mouse Distribution")
plt.axis("equal")
plt.savefig("../Images/pyplot_pie_plot.png")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
Capomulin_df = merged_data.loc[merged_data["Drug Regimen"] == "Capomulin",:]
Ramicane_df = merged_data.loc[merged_data["Drug Regimen"] == "Ramicane", :]
Infubinol_df = merged_data.loc[merged_data["Drug Regimen"] == "Infubinol", :]
Ceftamin_df = merged_data.loc[merged_data["Drug Regimen"] == "Ceftamin", :]

# %%
# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # add subset 
    # Determine outliers using upper and lower bounds

# Capomulin
Capomulin_max = Capomulin_df.groupby('Mouse ID').max()['Timepoint']
Capomulin_vol = pd.DataFrame(Capomulin_max)
Capomulin_merge = pd.merge(Capomulin_vol, merged_data, on=("Mouse ID","Timepoint"),how="left")
Capomulin_merge.head()

Capomulin_tumors = Capomulin_merge["Tumor Volume (mm3)"]

quartiles = Capomulin_tumors.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Capomulin tumors: {lowerq}")
print(f"The upper quartile of Capomulin tumors: {upperq}")
print(f"The interquartile range of Capomulin tumors: {iqr}")
print(f"The median of Capomulin tumors: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Capomulin tumors: 32.37735684
# The upper quartile of Capomulin tumors: 40.1592203
# The interquartile range of Capomulin tumors: 7.781863460000004
# The median of Capomulin tumors: 38.1251644
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.

# %%
# Ramicane
Ramicane_max = Ramicane_df.groupby('Mouse ID').max()['Timepoint']
Ramicane_vol = pd.DataFrame(Ramicane_max)
Ramicane_merge = pd.merge(Ramicane_vol, merged_data, on=("Mouse ID","Timepoint"),how="left")
Ramicane_merge.head()

Ramicane_tumors = Ramicane_merge["Tumor Volume (mm3)"]

quartiles = Ramicane_tumors.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Ramicane tumors: {lowerq}")
print(f"The upper quartile of Ramicane tumors: {upperq}")
print(f"The interquartile range of Ramicane tumors: {iqr}")
print(f"The median of Ramicane tumors: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Ramicane tumors: 31.56046955
# The upper quartile of Ramicane tumors: 40.65900627
# The interquartile range of Ramicane tumors: 9.098536719999998
# The median of Ramicane tumors: 36.56165229
# Values below 17.912664470000003 could be outliers.
# Values above 54.30681135 could be outliers.

# %%
# Infubinol
Infubinol_max = Infubinol_df.groupby('Mouse ID').max()['Timepoint']
Infubinol_vol = pd.DataFrame(Infubinol_max)
Infubinol_merge = pd.merge(Infubinol_vol, merged_data, on=("Mouse ID","Timepoint"),how="left")
Infubinol_merge.head()

Infubinol_tumors = Infubinol_merge["Tumor Volume (mm3)"]

quartiles = Infubinol_tumors.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Infubinol tumors: {lowerq}")
print(f"The upper quartile of Infubinol tumors: {upperq}")
print(f"The interquartile range of Infubinol tumors: {iqr}")
print(f"The median of Infubinol tumors: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Infubinol tumors: 54.04860769
# The upper quartile of Infubinol tumors: 65.52574285
# The interquartile range of Infubinol tumors: 11.477135160000003
# The median of Infubinol tumors: 60.16518046
# Values below 36.83290494999999 could be outliers.
# Values above 82.74144559000001 could be outliers.

# %%
# Ceftamin
Ceftamin_max = Ceftamin_df.groupby('Mouse ID').max()['Timepoint']
Ceftamin_vol = pd.DataFrame(Ceftamin_max)
Ceftamin_merge = pd.merge(Ceftamin_vol, merged_data, on=("Mouse ID","Timepoint"),how="left")
Ceftamin_merge.head()

Ceftamin_tumors = Ceftamin_merge["Tumor Volume (mm3)"]

quartiles = Ceftamin_tumors.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Ceftamin tumors: {lowerq}")
print(f"The upper quartile of Ceftamin tumors: {upperq}")
print(f"The interquartile range of Ceftamin tumors: {iqr}")
print(f"The median of Ceftamin tumors: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Ceftamin tumors: 48.72207785
# The upper quartile of Ceftamin tumors: 64.29983003
# The interquartile range of Ceftamin tumors: 15.577752179999997
# The median of Ceftamin tumors: 59.85195552
# Values below 25.355449580000002 could be outliers.
# Values above 87.66645829999999 could be outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
box_plot_data = [Capomulin_tumors, Ramicane_tumors, Infubinol_tumors, Ceftamin_tumors]
outlier_dot = dict(markerfacecolor='red',markersize=12)

fig1, ax1 = plt.subplots()
ax1.boxplot([Capomulin_tumors, Ramicane_tumors, Infubinol_tumors, Ceftamin_tumors], labels=["Capomulin","Ramicane","Infubinol","Ceftamin"], flierprops=outlier_dot)

ax1.set_title("Final Tumor Volumes")
ax1.set_ylabel("Tumor Volume (mm3)")
ax1.set_xlabel("Drug Regimen")
plt.savefig("../Images/box_plot.png")
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
Capomulin_df = merged_data.loc[merged_data["Drug Regimen"] == "Capomulin",:]
mouse_capomulin_j246_df = Capomulin_df.loc[Capomulin_df["Mouse ID"] =="j246",:]
mouse_capomulin_j246_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 310     j246    Capomulin  Female          21          21          0
# 311     j246    Capomulin  Female          21          21          5
# 312     j246    Capomulin  Female          21          21         10
# 313     j246    Capomulin  Female          21          21         15
# 314     j246    Capomulin  Female          21          21         20
# 315     j246    Capomulin  Female          21          21         25
# 316     j246    Capomulin  Female          21          21         30
# 317     j246    Capomulin  Female          21          21         35
#
#      Tumor Volume (mm3)  Metastatic Sites
# 310           45.000000                 0
# 311           45.641438                 0
# 312           46.408361                 0
# 313           43.312654                 0
# 314           44.020370                 0
# 315           44.555226                 0
# 316           38.044082                 1
# ...

# %%
mouse_capomulin_j246_df = mouse_capomulin_j246_df.loc[:,["Timepoint", "Tumor Volume (mm3)"]]
mouse_capomulin_j246_df
# Out:
#      Timepoint  Tumor Volume (mm3)
# 310          0           45.000000
# 311          5           45.641438
# 312         10           46.408361
# 313         15           43.312654
# 314         20           44.020370
# 315         25           44.555226
# 316         30           38.044082
# 317         35           38.753265

# %%
plt.plot(mouse_capomulin_j246_df["Timepoint"], mouse_capomulin_j246_df["Tumor Volume (mm3)"], marker="o", markersize=10, linewidth=2.5, color='blue')
plt.xlabel('Timepoint (Days)',fontsize =14)
plt.ylabel('Tumor Volume (mm3)',fontsize =14)
plt.title("Tumor Volume vs. Time Point for a Mouse-j246 Treated with Capomulin")
plt.savefig("../Images/lineplot_mouse_j246.png")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
mouse_weight = merged_data.loc[merged_data["Drug Regimen"] == "Capomulin"]
tumor_mean = mouse_weight.groupby(["Mouse ID"]).mean()

plt.scatter(tumor_mean["Weight (g)"], tumor_mean["Tumor Volume (mm3)"], s=65, color='blue')
plt.xlabel('Weight',fontsize =14)
plt.ylabel('Tumor Volume (mm3)',fontsize =14)
plt.title("Average Tumor Volume vs. Mouse Weight for the Capomulin")
plt.savefig("../Images/scatter_plot.png")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
x_values = tumor_mean["Weight (g)"]
y_values = tumor_mean["Tumor Volume (mm3)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values=x_values * slope + intercept
line_eq= f"y = {round(slope, 2)} x + {round(intercept, 2)}"
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, color='red')
plt.annotate(line_eq,(20,35), color='red', fontsize=15)
plt.xlabel("Weight")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Weight vs Tumor Volume for Capomulin")
plt.savefig("../Images/scatter_correlation_regression_.png")
plt.show()

# %%
print(f"Correlation between these two variables is {round(rvalue,2)}")
# Out:
# Correlation between these two variables is 0.84
